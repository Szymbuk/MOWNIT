# %%
import scipy
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import os

# Zmienia ścieżkę jeżeli jest konieczne
if os.path.basename(os.getcwd()) != "lab7":
    try:
        os.chdir("lab7")
        print("Zmieniono katalog roboczy na: ", os.getcwd())
    except FileNotFoundError:
        print("Błąd: Upewnij się, gdzie jesteś. Aktualny folder to:", os.getcwd())
# Out:
# Zmieniono katalog roboczy na:  /mnt/c/Users/szyme/Desktop/programowanie i projekty/MOWNiT/MOWNIT/lab7

# %%
data = pd.read_csv("./ex1_data.csv", delimiter=';')

# %% [markdown]
# $$v = \sqrt{\frac{2}{m} \int_{0}^{L} F \, dx}$$

# %%
M = 0.075
integral_result = scipy.integrate.simpson(data.F,data.x)
result = np.sqrt(2/M * integral_result)
print(result)
# Out:
# 44.58200932613464
