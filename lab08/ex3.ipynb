# %% [markdown]
# # a)

# %% [markdown]
# $$f(x) = \frac{1}{x} - c$$
#
# $$f'(x) = -\frac{1}{x^2}$$
#
# $$x_{k+1} = x_k - \frac{\frac{1}{x_k} - c}{-\frac{1}{x_k^2}} = x_k + x_k^2\left(\frac{1}{x_k} - c\right) = x_k(2 - c x_k)$$

# %%
f = lambda x,c: 1/c -c
f_der = lambda x: -1/(x**2)
x_next = lambda x_curr,c: x_curr*(2-c*x_curr)

# %% [markdown]
# # b)

# %% [markdown]
# $$f(x) = \frac{1}{x^2} - c$$
#
# $$f'(x) = -\frac{2}{x^3}$$
#
# $$x_{k+1} = x_k - \frac{\frac{1}{x_k^2} - c}{-\frac{2}{x_k^3}} = x_k - \frac{x_k^3}{-2} \left(\frac{1}{x_k^2} - c\right) = x_k + \frac{x_k-c x_k^3}{2}$$

# %% [markdown]
# # c)

# %% [markdown]
# $$f(x) = x^2 - c$$
#
# $$f'(x) = 2x$$
#
# $$x_{k+1} = x_k - \frac{x^2 - c}{2 x_k} = x_k - \frac{x_k}{2} + \frac{c}{2 x_k} = \frac{1}{2} (x_k + \frac{c}{x_k})$$

# %% [markdown]
# # d)

# %% [markdown]
# Używamy iteracji Newtona z podpunktu b, następnie mnożymy otrzymany wynik przez c, w ten sposób otrzymujemy $\sqrt{c}$
